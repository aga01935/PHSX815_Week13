# %% [markdown]
# <a href="https://colab.research.google.com/github/aga01935/PHSX815_Week13/blob/main/Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
#Generating isotropic gaussian blobs/data
X, Y = make_blobs(n_samples=1000, centers=5,cluster_std=0.8, random_state=0)




#Applying Kmeans Clustering  to data
Z = KMeans(6, random_state=0)
#V = Z.fit(X).predict(X)
#Plot
#plt.figure()
#plt.plot(X[:, 0])
#plt.figure()
#plt.plot(X[:, 1])
#plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=V);
plt.show()
